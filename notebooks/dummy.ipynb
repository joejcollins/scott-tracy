# %% [markdown]
# # Dummy Notebook
#
# Doing something dumb.

# %%
"""Dummy helper demonstration."""
from helheim import dummy_helper

new_number = dummy_helper.add_things(1, 2)

print(new_number)
# Out:
# 2025-02-19 14:51:59.887 | INFO     | helheim.config:<module>:11 - PROJ_ROOT path is: /home/joejc/helheim/src
# 3

# %% [markdown]
# # Dummy Plot
#
# Yes, it's dumb.

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 35]

# Create a line plot
plt.plot(x, y, marker='o')
plt.title('Sample Line Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.grid()
plt.show()
